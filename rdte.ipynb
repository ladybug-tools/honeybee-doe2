# %%
from honeybee.model import Model
from honeybee.room import Room
from honeybee.face import Face
from honeybee.shade import Shade
from honeybee.aperture import Aperture
from honeybee.door import Door
from honeybee.boundarycondition import Surface
from honeybee.facetype import face_types
from honeybee.units import conversion_factor_to_meters

from ladybug_geometry.geometry3d.pointvector import Point3D, Vector3D
from ladybug_geometry.geometry3d.plane import Plane
from ladybug_geometry.geometry3d.face import Face3D

from honeybee_doe2.writer import model_to_inp #prolly need to add this as a model function... 
from pprint import pprint


tmodel = Model.from_hbjson('samples\cubetower.hbjson')

#inp_model = model_to_inp(tmodel)
#with open('test.inp', 'w') as f:
#    f.write(inp_model)
#    f.close

for s in tmodel.properties.doe2.stories:
    print(s.story_poly)
# Out:
# "Level_0 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    V5        = ( 20.000000, 10.000000 )
#    V6        = ( 20.000000, 0.000000 )
#    V7        = ( 10.000000, 0.000000 )
#    V8        = ( 0.000000, 0.000000 )
#    V9        = ( 0.000000, 0.000000 )
#    V10        = ( 0.000000, 10.000000 )
#    V11        = ( 0.000000, 10.000000 )
#    V12        = ( 10.000000, 10.000000 )
#    ..
# "Face 51f25 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 0.000000, 0.000000 )
#    ..
#
# "Face 9764a Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face 375f2 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 0.000000, 10.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 4ee55 Plg" = POLYGON
#    V1        = ( 0.000000, 10.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 0.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 6fbac Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 7c8ec Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 4724b Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 0.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face c7096 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 20.000000, 10.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 20.000000, 0.000000 )
#    ..
#
# "Face 6ab51 Plg" = POLYGON
#    V1        = ( 20.000000, 10.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face af261 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 8f26e Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face bfbf6 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
# "Level_1 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    V5        = ( 20.000000, 10.000000 )
#    V6        = ( 20.000000, 0.000000 )
#    V7        = ( 10.000000, 0.000000 )
#    V8        = ( 0.000000, 0.000000 )
#    V9        = ( 0.000000, 0.000000 )
#    V10        = ( 0.000000, 10.000000 )
#    V11        = ( 0.000000, 10.000000 )
#    V12        = ( 10.000000, 10.000000 )
#    ..
# "Face 94efb Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 0.000000, 0.000000 )
#    ..
#
# "Face 5a71d Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face 8afa0 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 0.000000, 10.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 9f77d Plg" = POLYGON
#    V1        = ( 0.000000, 10.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 0.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 1f454 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face a2f6c Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 46914 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 0.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face cd7db Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 20.000000, 10.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 20.000000, 0.000000 )
#    ..
#
# "Face f0ecd Plg" = POLYGON
#    V1        = ( 20.000000, 10.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face 223ce Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 9e7d3 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face e3e14 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
# "Level_2 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    V5        = ( 20.000000, 10.000000 )
#    V6        = ( 20.000000, 0.000000 )
#    V7        = ( 10.000000, 0.000000 )
#    V8        = ( 0.000000, 0.000000 )
#    V9        = ( 0.000000, 0.000000 )
#    V10        = ( 0.000000, 10.000000 )
#    V11        = ( 0.000000, 10.000000 )
#    V12        = ( 10.000000, 10.000000 )
#    ..
# "Face 86932 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 0.000000, 0.000000 )
#    ..
#
# "Face e577c Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face 77df3 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 0.000000, 10.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face cf5b3 Plg" = POLYGON
#    V1        = ( 0.000000, 10.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 0.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face fb9d4 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face a2084 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 2c00e Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 0.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face 5fb85 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 20.000000, 10.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 20.000000, 0.000000 )
#    ..
#
# "Face 8cc10 Plg" = POLYGON
#    V1        = ( 20.000000, 10.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face 16ae2 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face ca764 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face 44489 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
# "Level_3 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    V5        = ( 20.000000, 10.000000 )
#    V6        = ( 20.000000, 0.000000 )
#    V7        = ( 10.000000, 0.000000 )
#    V8        = ( 0.000000, 0.000000 )
#    V9        = ( 0.000000, 0.000000 )
#    V10        = ( 0.000000, 10.000000 )
#    V11        = ( 0.000000, 10.000000 )
#    V12        = ( 10.000000, 10.000000 )
#    ..
# "Face 70a90 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 0.000000, 0.000000 )
#    ..
#
# "Face c0731 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face db9ef Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 0.000000, 10.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 5ed31 Plg" = POLYGON
#    V1        = ( 0.000000, 10.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 0.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 1ee43 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face f7cd6 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face 69439 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 0.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face 23b96 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 20.000000, 10.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 20.000000, 0.000000 )
#    ..
#
# "Face 37443 Plg" = POLYGON
#    V1        = ( 20.000000, 10.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face a57ac Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 5478d Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face af1aa Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
# "Level_4 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    V5        = ( 20.000000, 10.000000 )
#    V6        = ( 20.000000, 0.000000 )
#    V7        = ( 10.000000, 0.000000 )
#    V8        = ( 0.000000, 0.000000 )
#    V9        = ( 0.000000, 0.000000 )
#    V10        = ( 0.000000, 10.000000 )
#    V11        = ( 0.000000, 10.000000 )
#    V12        = ( 10.000000, 10.000000 )
#    ..
# "Face 991b8 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 0.000000, 0.000000 )
#    ..
#
# "Face 2c0c2 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face c8647 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 0.000000, 10.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 179a5 Plg" = POLYGON
#    V1        = ( 0.000000, 10.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 0.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face eecbe Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 0.000000, 0.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face e4291 Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 0.000000, 10.000000 )
#    ..
#
# "Face e10cf Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 0.000000 )
#    V4        = ( 10.000000, 0.000000 )
#    ..
#
# "Face f29b0 Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 20.000000, 10.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 20.000000, 0.000000 )
#    ..
#
# "Face 0e29a Plg" = POLYGON
#    V1        = ( 20.000000, 10.000000 )
#    V2        = ( 10.000000, 10.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face 66110 Plg" = POLYGON
#    V1        = ( 10.000000, 10.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 0.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..
#
# "Face 2403e Plg" = POLYGON
#    V1        = ( 20.000000, 0.000000 )
#    V2        = ( 10.000000, 0.000000 )
#    V3        = ( 10.000000, 10.000000 )
#    V4        = ( 20.000000, 10.000000 )
#    ..
#
# "Face 376c7 Plg" = POLYGON
#    V1        = ( 10.000000, 0.000000 )
#    V2        = ( 20.000000, 0.000000 )
#    V3        = ( 20.000000, 10.000000 )
#    V4        = ( 10.000000, 10.000000 )
#    ..

# %%
from honeybee.model import Model
from honeybee.room import Room
from honeybee.face import Face
from honeybee.shade import Shade
from honeybee.aperture import Aperture
from honeybee.door import Door
from honeybee.boundarycondition import Surface
from honeybee.facetype import face_types
from honeybee.units import conversion_factor_to_meters

from ladybug_geometry.geometry3d.pointvector import Point3D, Vector3D
from ladybug_geometry.geometry3d.plane import Plane
from ladybug_geometry.geometry3d.face import Face3D

from honeybee_doe2.writer import model_to_inp #prolly need to add this as a model function... 
from pprint import pprint

from honeybee_doe2.properties.story import Doe2Story


tmodel = Model.from_hbjson('samples\cubetower.hbjson')

group_tupe = Room.group_by_floor_height(tmodel.rooms, 0.1)

stories = []

for i, story in enumerate(group_tupe[0]):
    stories.append(Doe2Story(story,i))

   
print(stories[0])
# Out:
# "Level_0"= FLOOR
#    SHAPE           = POLYGON
#    POLYGON         = "Level_0 Plg"
#    FLOOR-HEIGHT    = 0.0
#    ..
#
# "Room 43ee2" = SPACE
#    SHAPE           = POLYGON
#    POLYGON         = "Room 43ee2 Plg"
#
# "Face 51f25" = EXTERIOR-WALL
#   POLYGON           = "Face 51f25 Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  180.0
#   X                 =  0.0
#   Y                 =  0.0
#   Z                 =  0.0
# ..
#
#
# "Face 9764a" = INTERIOR-WALL
#   POLYGON           = "Face 9764a Plg"
#   CONSTRUCTION      = "Generic Interior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  90.0
#   X                 =  10.0
#   Y                 =  0.0
#   Z                 =  0.0
# ..
#
#
# "Face 375f2" = EXTERIOR-WALL
#   POLYGON           = "Face 375f2 Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  0.0
#   X                 =  10.0
#   Y                 =  10.0
#   Z                 =  0.0
# ..
#
#
# "Face 4ee55" = EXTERIOR-WALL
#   POLYGON           = "Face 4ee55 Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  270.0
#   X                 =  0.0
#   Y                 =  10.0
#   Z                 =  0.0
# ..
#
#
# "Room 28562" = SPACE
#    SHAPE           = POLYGON
#    POLYGON         = "Room 28562 Plg"
#
# "Face 4724b" = EXTERIOR-WALL
#   POLYGON           = "Face 4724b Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  180.0
#   X                 =  10.0
#   Y                 =  0.0
#   Z                 =  0.0
# ..
#
#
# "Face c7096" = EXTERIOR-WALL
#   POLYGON           = "Face c7096 Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  90.0
#   X                 =  20.0
#   Y                 =  0.0
#   Z                 =  0.0
# ..
#
#
# "Face 6ab51" = EXTERIOR-WALL
#   POLYGON           = "Face 6ab51 Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  0.0
#   X                 =  20.0
#   Y                 =  10.0
#   Z                 =  0.0
# ..
#
#
# "Face af261" = INTERIOR-WALL
#   POLYGON           = "Face af261 Plg"
#   CONSTRUCTION      = "Generic Interior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  270.0
#   X                 =  10.0
#   Y                 =  10.0
#   Z                 =  0.0
# ..

# %%
rm = tmodel.rooms[0]

rm.properties.doe2.walls
# Out:
# ["Face 51f25" = EXTERIOR-WALL
#    POLYGON           = "Face 51f25 Plg"
#    CONSTRUCTION      = "Generic Exterior Wall"
#    TILT              =  90.0
#    AZIMUTH           =  180.0
#    X                 =  0.0
#    Y                 =  0.0
#    Z                 =  0.0
#  ..,
#  "Face 9764a" = INTERIOR-WALL
#    POLYGON           = "Face 9764a Plg"
#    CONSTRUCTION      = "Generic Interior Wall"
#    TILT              =  90.0
#    AZIMUTH           =  90.0
#    X                 =  10.0
#    Y                 =  0.0
#    Z                 =  0.0
#  ..,
#  "Face 375f2" = EXTERIOR-WALL
#    POLYGON           = "Face 375f2 Plg"
#    CONSTRUCTION      = "Generic Exterior Wall"
#    TILT              =  90.0
#    AZIMUTH           =  0.0
#    X                 =  10.0
#    Y                 =  10.0
#    Z                 =  0.0
#  ..,
#  "Face 4ee55" = EXTERIOR-WALL
#    POLYGON           = "Face 4ee55 Plg"
#    CONSTRUCTION      = "Generic Exterior Wall"
#    TILT              =  90.0
#    AZIMUTH           =  270.0
#    X                 =  0.0
#    Y                 =  10.0
#    Z                 =  0.0
#  ..]

# %%
tmodel.stories
# Out:
# ['0', '3', '13', '2', '1']

# %%
from honeybee_energy.material.glazing import EnergyWindowMaterialGlazing
from honeybee_energy.material.gas import EnergyWindowMaterialGas
from honeybee_energy.construction.window import WindowConstruction

from honeybee_doe2.properties.inputils.glass_types import GlassType


lowe_glass = EnergyWindowMaterialGlazing(
        'Low-e Glass', 0.00318, 0.4517, 0.359, 0.714, 0.207,
        0, 0.84, 0.046578, 1.0)
clear_glass = EnergyWindowMaterialGlazing(
        'Clear Glass', 0.005715, 0.770675, 0.07, 0.8836, 0.0804,
        0, 0.84, 0.84, 1.0)
gap = EnergyWindowMaterialGas('air gap', thickness=0.0127)
double_low_e = WindowConstruction(
        'Double Low-E Window', [lowe_glass, gap, clear_glass])

test_type = GlassType.from_hb_window_constr(double_low_e)
print(test_type.to_inp())
# Out:
# "Double Low-E Window" = GLASS-TYPE
#    TYPE               = SHADING-COEF
#    SHADING-COEF       = 0.48810970326870606
#    GLASS-CONDUCT      = 0.299
#    ..

# %%
from honeybee.face import Face
from honeybee.facetype import face_types, Wall
from ladybug_geometry.geometry3d.face import Face3D
from ladybug_geometry.geometry3d.pointvector import Point3D, Vector3D
from ladybug_geometry.geometry3d.plane import Plane
import uuid as py_uuid
from honeybee_doe2.geometry.polygon import DoePolygon as doepoly
from pprint import pprint

vertices = [Point3D(0, 0, 0), Point3D(0, 10, 0), Point3D(0, 10, 3), Point3D(0, 0, 3)]

unique_id = str(py_uuid.uuid4())
face = Face(unique_id, Face3D(vertices))
face.display_name = 'Walltest'


testpoly = doepoly.from_face(face)
testpoly
# Out:
# "Walltest Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( 0.000000, 10.000000 )
#    V3        = ( 0.000000, 10.000000 )
#    V4        = ( 0.000000, 0.000000 )
#    ..

# %%
print(face.properties.doe2.poly)
# Out:
# '"Walltest Plg" = POLYGON\n   V1        = ( 0.000000, 0.000000 )\n   V2        = ( 0.000000, 10.000000 )\n   V3        = ( 0.000000, 10.000000 )\n   V4        = ( 0.000000, 0.000000 )\n   ..'

# %%
from honeybee_doe2.properties.inputils.title import Title

test = Title(title='sdf')
print(str(test.to_inp()))
# Out:
# TITLE
#     LINE-1           = *sdf*
#     ..

# %%
from honeybee_doe2.properties.inputils.sitebldg import SiteBldgData as sbd



abc = sbd()

print(abc.to_inp())
# Out:
# $---------------------------------------------------------
# $              Site and Building Data
# $---------------------------------------------------------
#
# "Site Data" = SITE-PARAMETERS
#   ALTITUDE          = 150
#   C-STATE           = 21
#   C-WEATHER-FILE    = *TMY2\HARTFOCT.bin*
#   C-COUNTRY         = 1
#   C-901-LOCATION    = 1092
#   ..
# "Building Data" = BUILD-PARAMETERS
#   HOLIDAYS        = "Standard US Holidays"
#   ..
#
#
# PROJECT-DATA
#   ..

# %%
from honeybee.room import Room

room = Room.from_box('mybox', 3,3,3)


#print(room.properties.doe2.space)
#print(room.properties.doe2.poly)
# Out:
# "mybox" = SPACE
#    SHAPE           = POLYGON
#    POLYGON         = "mybox Plg"
#    C-ACTIVITY-DESC = *Program Type: Plenum*
#    ..
#
# None

# %%
from honeybee.face import Face
from honeybee.facetype import face_types, Wall
from ladybug_geometry.geometry3d.face import Face3D
from ladybug_geometry.geometry3d.pointvector import Point3D, Vector3D
from ladybug_geometry.geometry3d.plane import Plane
import uuid as py_uuid
from honeybee_doe2.geometry.polygon import DoePolygon as doepoly
from pprint import pprint

vertices = [Point3D(0, 0, 0), 
            Point3D(0, 10, 0), 
            Point3D(0, 10, 3), 
            Point3D(0, 0, 3)]

unique_id = str(py_uuid.uuid4())
test_face = Face(unique_id, Face3D(vertices))
test_face.display_name = 'Walltest'

class WallStuff:
    def __init__(self, _face):
        self.host = _face
        
    @property
    def wall_poly(self):
        return self._create_wall_poly(self.host)
    
    @staticmethod
    def _create_wall_poly(obj):
        return doepoly.from_vertices(name=obj.display_name, vertices=obj.geometry.polygon2d.vertices)
        
        
mywall = WallStuff(test_face)

mywall.wall_poly
# Out:
# "Walltest Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( -10.000000, 0.000000 )
#    V3        = ( -10.000000, -3.000000 )
#    V4        = ( 0.000000, -3.000000 )
#    ..

# %%
from honeybee_doe2.properties.wall import DoeWall

new_wall = WallStuff(test_face)
new_wall.wall_poly
# Out:
# "Walltest Plg" = POLYGON
#    V1        = ( 0.000000, 0.000000 )
#    V2        = ( -10.000000, 0.000000 )
#    V3        = ( -10.000000, -3.000000 )
#    V4        = ( 0.000000, -3.000000 )
#    ..

# %%
from honeybee.face import Face
from honeybee.facetype import face_types, Wall
from ladybug_geometry.geometry3d.face import Face3D
from ladybug_geometry.geometry3d.pointvector import Point3D, Vector3D
from ladybug_geometry.geometry3d.plane import Plane
import uuid as py_uuid
from honeybee_doe2.geometry.polygon import DoePolygon as doepoly
from pprint import pprint
from honeybee.room import Room

vertices = [Point3D(0, 0, 0), Point3D(0, 10, 0), Point3D(0, 10, 3), Point3D(0, 0, 3)]

unique_id = str(py_uuid.uuid4())
test_face = Face(unique_id, Face3D(vertices))
test_face.display_name = 'doetestwall'

from honeybee_doe2.properties.wall import DoeWall

mywall = DoeWall(_face=test_face)


room = Room.from_box('mybox', 3,3,3)

mywall = DoeWall(_face=room.faces[1])

mywall.wall_obj
# Out:
# "mybox_Front" = EXTERIOR-WALL
#   POLYGON           = "mybox_Front Plg"
#   CONSTRUCTION      = "Generic Exterior Wall"
#   TILT              =  90.0
#   AZIMUTH           =  0.0
#   X                 =  3.0
#   Y                 =  3.0
#   Z                 =  0.0
# ..
